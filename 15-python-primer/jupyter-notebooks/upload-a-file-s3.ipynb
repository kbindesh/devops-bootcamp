# %%
import boto3

# %%
s3 = boto3.client('s3')

# %%
# Upload file (Local file path, Bucket name, S3 object name)
s3.upload_file('hello.txt', 'my-bucket-name', 'hello.txt')
print("Upload successful!")
