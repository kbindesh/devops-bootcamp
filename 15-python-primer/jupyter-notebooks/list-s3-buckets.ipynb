# %%
import boto3

# %%
s3 = boto3.client('s3')

# %%
bucket_list = s3.list_buckets()

# Print the name of each bucket
for bucket in bucket_list['Buckets']:
    print(f"Bucket Name: {bucket['Name']}")
# Out:
# Bucket Name: bin-lab-bucket-2804
# Bucket Name: primary-bucket-logs
# Bucket Name: s3-lab-bucket-2403
# Bucket Name: sample-s3-bucket-2304
# Bucket Name: terraform-state-info-0705
# Bucket Name: test-bucket-0305
